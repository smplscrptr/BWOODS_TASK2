# %% [markdown]
# # Bennett Woods Data Analysis

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import plotly.express as px
import pycountry

# %%
file_path = "GemDataEXTR/GDP at market prices, current US$, millions, seas. adj..xlsx"
df = pd.read_excel(file_path)

df.head()
# Out:
#    Unnamed: 0   Albania  Advanced Economies  Argentina  Armenia  Australia  \
# 0         NaN       NaN                 NaN        NaN      NaN        NaN
# 1      1996.0  3289.029          25529847.0   304162.6      NaN   424835.0
# 2      1997.0  2280.960          25017024.0   327324.5      NaN   425689.6
# 3      1998.0  2560.395          25121292.0   334208.9      NaN   381265.3
# 4      1999.0  3292.612          26448508.0   317253.9      NaN   412018.0
#
#     Austria   Belgium  Bulgaria  Bahrain  ...  Thailand  Tunisia    Turkey  \
# 0       NaN       NaN       NaN      NaN  ...       NaN      NaN       NaN
# 1  234258.1  276714.3  13731.15      NaN  ...  182968.0      NaN  249290.9
# 2  212463.9  253536.6  11333.61      NaN  ...  156986.3      NaN  266162.7
# 3  217468.0  259194.1  15015.97      NaN  ...  114644.2      NaN  272610.5
# 4  216273.5  258289.0  13587.52      NaN  ...  126556.0      NaN  252512.0
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Albania', 'Advanced Economies', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Belgium', 'Bulgaria', 'Bahrain',
#        ...
#        'Thailand', 'Tunisia', 'Turkey', 'Taiwan, China', 'Ukraine', 'Uruguay',
#        'United States', 'Uzbekistan', 'World (WBG members)', 'South Africa'],
#       dtype='object', length=105)

# %%
df.dtypes.value_counts()
# Out:
# float64    105
# Name: count, dtype: int64

# %%
df.info()
df.shape
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Columns: 105 entries, Unnamed: 0 to South Africa
# dtypes: float64(105)
# memory usage: 25.6 KB
#         Unnamed: 0       Albania  Advanced Economies      Argentina  \
# count    30.000000     29.000000        3.000000e+01      29.000000
# mean   2010.500000  11225.230862        4.131084e+07  415862.400000
# std       8.803408   6204.820667        1.248924e+07  167144.531473
# min    1996.000000   2280.960000        1.634543e+07  116452.800000
# 25%    2003.250000   5810.928000        2.865149e+07  304162.600000
# 50%    2010.500000  12103.020000        4.386305e+07  386069.300000
# 75%    2017.750000  13404.930000        4.870184e+07  562805.200000
# max    2025.000000  27128.950000        6.454681e+07  648542.700000
#
#             Armenia     Australia        Austria        Belgium  \
# count     26.000000  3.000000e+01      30.000000      30.000000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              1
# Albania                 2
# Advanced Economies      1
# Argentina               2
# Armenia                 5
#                        ..
# Uruguay                 2
# United States           1
# Uzbekistan             11
# World (WBG members)     1
# South Africa            1
# Length: 105, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(how="all", inplace=True)
df.rename(columns={"Unnamed: 0": "Year"}, inplace=True)
df["Year"] = pd.to_numeric(df["Year"], errors="coerce")

df.sort_values(by="Year", inplace=True)

# %%
df_interp = df.copy()
df_interp.set_index("Year", inplace=True)

df_interp = df_interp.interpolate(method="linear", axis=0)

df_interp.reset_index(inplace=True)

df_interp.head()
# Out:
# /var/folders/gl/f1ntj1j13hl11vblkvljlqbw0000gn/T/ipykernel_88739/3949865843.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_interp.reset_index(inplace=True)
#      Year   Albania  Advanced Economies  Argentina   Armenia  Australia  \
# 0  1996.0  3289.029          25529847.0   304162.6       NaN   424835.0
# 1  1997.0  2280.960          25017024.0   327324.5       NaN   425689.6
# 2  1998.0  2560.395          25121292.0   334208.9       NaN   381265.3
# 3  1999.0  3292.612          26448508.0   317253.9       NaN   412018.0
# 4  2000.0  3577.642          26893751.0   318021.7  2105.325   399608.9
#
#     Austria   Belgium  Bulgaria  Bahrain  ...  Thailand   Tunisia    Turkey  \
# ...

# %%
df_long = df_interp.melt(id_vars="Year", var_name="Country", value_name="GDP")
df_long = df_long.dropna(subset=["GDP"])

df_long.head()
# Out:
#      Year  Country       GDP
# 0  1996.0  Albania  3289.029
# 1  1997.0  Albania  2280.960
# 2  1998.0  Albania  2560.395
# 3  1999.0  Albania  3292.612
# 4  2000.0  Albania  3577.642

# %%
latest_year = df_long["Year"].max()
top_countries = df_long[df_long["Year"] == latest_year].nlargest(5, "GDP")["Country"].tolist()

if "United States" not in top_countries:
    top_countries.append("United States")

df_top = df_long[df_long["Country"].isin(top_countries)]

plt.figure(figsize=(14, 6))
sns.lineplot(data=df_top, x="Year", y="GDP", hue="Country")
plt.title("GDP Over Time for Selected Countries")
plt.ylabel("GDP")
plt.xlabel("Year")
plt.legend(title="Country")
plt.tight_layout()
plt.show()
